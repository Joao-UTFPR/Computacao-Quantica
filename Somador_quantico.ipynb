# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram, plot_distribution

# %%
siml = AerSimulator()
qcirc = QuantumCircuit(4, 2)
qcirc.cx(1,2)
qcirc.cx(0,2)
qcirc.ccx(0,1,3)
qcirc.measure(2,0)
qcirc.measure(3,1)
qcirc.draw("mpl", initial_state=True)
